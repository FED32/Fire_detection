# %% [markdown]
# <a href="https://colab.research.google.com/github/FED32/Fire_detection/blob/main/%22Fire_detection_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Датасет
# https://github.com/cair/Fire-Detection-Image-Dataset.git
#
# Еще датасет
# https://www.kaggle.com/datasets/phylake1337/fire-dataset
#
# Статья
# https://habr.com/ru/company/nix/blog/441620/
#
# Еще статья
# https://habr.com/ru/post/598617/
#
# Пример моей учебной работы по дообучению сети VGG16
# https://www.kaggle.com/code/fed9211/my-cats-vs-dogs
#
# Документация keras
# https://keras.io/api/
#
# Документация resnet
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/preprocess_input

# %%
import numpy as np
import pandas as pd

import cv2
import tensorflow as tf
from tensorflow.keras.applications import resnet50
from keras.callbacks import EarlyStopping, ModelCheckpoint

print(tf.__version__)
print(tf.executing_eagerly())

import os
from random import shuffle
from glob import glob

from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

from tqdm import tqdm
# Out:
# 2.8.0
# True

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# загружаем картинки
fire_images = glob('gdrive/MyDrive/Fire_detecting/data/dataset/Fire images 1/*.jpg') + \
glob('gdrive/MyDrive/Fire_detecting/data/dataset/Fire images 2/*.png')

normal_images = glob('gdrive/MyDrive/Fire_detecting/data/dataset/Normal Images 1/*.jpg') + \
glob('gdrive/MyDrive/Fire_detecting/data/dataset/Normal Images 2/*.jpg') + \
glob('gdrive/MyDrive/Fire_detecting/data/dataset/Normal Images 3/*.jpg') + \
glob('gdrive/MyDrive/Fire_detecting/data/dataset/Normal Images 4/*.jpg') + \
glob('gdrive/MyDrive/Fire_detecting/data/dataset/Normal Images 5/*.jpg') + \
glob('gdrive/MyDrive/Fire_detecting/data/dataset/Normal Images 6/*.png')

shuffle(fire_images)
shuffle(normal_images)

print(f'Количество картинок с пожаром', len(fire_images))
print(f'Количество обычных картинок', len(normal_images))
# Out:
# Количество картинок с пожаром 860
# Количество обычных картинок 761

# %%
IMG_SIZE = (224, 224)

# %%
# функция для отображения картинок
def show_images(files):
    fig = plt.figure(figsize=(16, 8))
    for i, path in enumerate(files[:10], 1):
        subplot = fig.add_subplot(2, 5, i)
        subplot.set_title('%s' % path.split('/')[-1])
        img = cv2.imread(path)[...,::-1]
        img = cv2.resize(img, IMG_SIZE)
        plt.imshow(img)
    return None

# %%
show_images(fire_images)

# %%
show_images(normal_images)

# %%
# функция для загрузки и предобработки изображения
def load_image(path, target_size=IMG_SIZE):
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, target_size)
    return resnet50.preprocess_input(img, data_format=None)

# функция-генератор загрузки обучающих данных с диска
def fit_generator(files, batch_size=32):
    batch_size = min(batch_size, len(files))
    while True:
        shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1 if os.path.dirname(path).split('/')[-1].startswith('Fire') else 0
                          for path in files[i:j]])
            yield (x, y)
            
            
# функция-генератор загрузки тестовых изображений с диска
def predict_generator(files):
    while True:
        for path in files:
            yield np.array([load_image(path)])

# %%
# разбиваем данные на тренировочные и тестовые
def get_train_test(files):
    train = files[:round(len(files)*0.8)]
    test = files[round(len(files)*0.8):]
    return train, test

train_files = get_train_test(fire_images)[0] + get_train_test(normal_images)[0]
test_files = get_train_test(fire_images)[1] + get_train_test(normal_images)[1]

shuffle(train_files)
shuffle(test_files)

print(f'Тренировочных изображений', len(train_files))
print(f'Тестовых изображений', len(test_files))
# Out:
# Тренировочных изображений 1297
# Тестовых изображений 324

# %%
# загружаем базовую модель
# base_model - объект класса keras.models.Model (Functional Model)
base_model = resnet50.ResNet50(weights='imagenet',
                         include_top=False,
                         input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
base_model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# фиксируем все веса предобученной сети
for layer in base_model.layers:
    layer.trainable = False

x = base_model.layers[-1].output
# x = tf.keras.layers.Dropout(rate=0.2, noise_shape=None, seed=None)(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(1,  # один выход (бинарная классификация)
                          activation='sigmoid',  # функция активации  
                          kernel_regularizer=tf.keras.regularizers.l1(1e-4))(x)

model = tf.keras.Model(inputs=base_model.input, outputs=x, name='fire_detector')

# %%
model.summary()
# Out:
# Model: "fire_detector"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  batch_normalization (BatchNorm  (None, 7, 7, 2048)  8192        ['conv5_block3_out[0][0]']
#  alization)
#
#  flatten (Flatten)              (None, 100352)       0           ['batch_normalization[0][0]']
#
#  dense (Dense)                  (None, 1)            100353      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 23,696,257
# Trainable params: 104,449
# Non-trainable params: 23,591,808
# __________________________________________________________________________________________________

# %%
# компилируем модель
model.compile(optimizer='adam', 
              loss='binary_crossentropy',  # функция потерь binary_crossentropy (log loss)
              metrics=['accuracy'])

# %%
# настраиваем чекпоинты
from keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(monitor='acc', min_delta=0.001,
                           patience=10, verbose=1, mode='auto')
chkpt = ModelCheckpoint('fire_detector.hdf5', 
                        monitor='loss', 
                        verbose=1, 
                        save_best_only=True, 
                        mode='auto')
callbacks = [early_stop, chkpt]

# %%
# формируем тренировочные и валидационные данные
val_samples = 5  # число изображений в валидационной выборке
epochs=100

shuffle(train_files)  # перемешиваем обучающую выборку
validation_data = next(fit_generator(train_files[:val_samples], val_samples))
train_data = fit_generator(train_files[val_samples:])  # данные читаем функцией-генератором

# %%
# запускаем процесс обучения
model.fit(train_data,
          steps_per_epoch=10,  # число вызовов генератора за эпоху
          epochs=epochs,  # число эпох обучения
          validation_data=validation_data,
          callbacks=callbacks)
# Out:
# Epoch 1/100
# 10/10 [==============================] - ETA: 0s - loss: 0.3574 - accuracy: 0.8969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 1: loss improved from inf to 0.35736, saving model to fire_detector.hdf5
# 10/10 [==============================] - 71s 6s/step - loss: 0.3574 - accuracy: 0.8969 - val_loss: 1.5532 - val_accuracy: 0.8000
# Epoch 2/100
# 10/10 [==============================] - ETA: 0s - loss: 0.3462 - accuracy: 0.9406WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 2: loss improved from 0.35736 to 0.34624, saving model to fire_detector.hdf5
# 10/10 [==============================] - 74s 8s/step - loss: 0.3462 - accuracy: 0.9406 - val_loss: 0.0541 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - ETA: 0s - loss: 0.4569 - accuracy: 0.9563WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 3: loss did not improve from 0.34624
# 10/10 [==============================] - 73s 7s/step - loss: 0.4569 - accuracy: 0.9563 - val_loss: 0.0589 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - ETA: 0s - loss: 0.4098 - accuracy: 0.9500WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 4: loss did not improve from 0.34624
# 10/10 [==============================] - 82s 8s/step - loss: 0.4098 - accuracy: 0.9500 - val_loss: 0.4844 - val_accuracy: 0.8000
# Epoch 5/100
# 10/10 [==============================] - ETA: 0s - loss: 0.2483 - accuracy: 0.9812WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 5: loss improved from 0.34624 to 0.24834, saving model to fire_detector.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.2483 - accuracy: 0.9812 - val_loss: 1.6550 - val_accuracy: 0.8000
# Epoch 6/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9906WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 6: loss improved from 0.24834 to 0.10307, saving model to fire_detector.hdf5
# 10/10 [==============================] - 11s 1s/step - loss: 0.1031 - accuracy: 0.9906 - val_loss: 1.3437 - val_accuracy: 0.8000
# Epoch 7/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1991 - accuracy: 0.9812WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 7: loss did not improve from 0.10307
# 10/10 [==============================] - 10s 1s/step - loss: 0.1991 - accuracy: 0.9812 - val_loss: 0.0801 - val_accuracy: 1.0000
# Epoch 8/100
# 10/10 [==============================] - ETA: 0s - loss: 0.2462 - accuracy: 0.9750WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 8: loss did not improve from 0.10307
# 10/10 [==============================] - 9s 907ms/step - loss: 0.2462 - accuracy: 0.9750 - val_loss: 0.0689 - val_accuracy: 1.0000
# Epoch 9/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1276 - accuracy: 0.9875WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 9: loss did not improve from 0.10307
# 10/10 [==============================] - 9s 880ms/step - loss: 0.1276 - accuracy: 0.9875 - val_loss: 0.0705 - val_accuracy: 1.0000
# Epoch 10/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1158 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 10: loss did not improve from 0.10307
# 10/10 [==============================] - 10s 1s/step - loss: 0.1158 - accuracy: 0.9937 - val_loss: 0.0713 - val_accuracy: 1.0000
# Epoch 11/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0945 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 11: loss improved from 0.10307 to 0.09446, saving model to fire_detector.hdf5
# 10/10 [==============================] - 12s 1s/step - loss: 0.0945 - accuracy: 0.9937 - val_loss: 0.0751 - val_accuracy: 1.0000
# Epoch 12/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 12: loss did not improve from 0.09446
# 10/10 [==============================] - 10s 1s/step - loss: 0.0956 - accuracy: 0.9937 - val_loss: 0.0763 - val_accuracy: 1.0000
# Epoch 13/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 13: loss improved from 0.09446 to 0.07727, saving model to fire_detector.hdf5
# 10/10 [==============================] - 10s 1s/step - loss: 0.0773 - accuracy: 0.9969 - val_loss: 0.0736 - val_accuracy: 1.0000
# Epoch 14/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1068 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 14: loss did not improve from 0.07727
# 10/10 [==============================] - 10s 1s/step - loss: 0.1068 - accuracy: 0.9937 - val_loss: 0.0731 - val_accuracy: 1.0000
# Epoch 15/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 15: loss improved from 0.07727 to 0.07360, saving model to fire_detector.hdf5
# 10/10 [==============================] - 10s 986ms/step - loss: 0.0736 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 1.0000
# Epoch 16/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 16: loss did not improve from 0.07360
# 10/10 [==============================] - 11s 1s/step - loss: 0.1307 - accuracy: 0.9937 - val_loss: 0.0732 - val_accuracy: 1.0000
# Epoch 17/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 17: loss did not improve from 0.07360
# 10/10 [==============================] - 12s 1s/step - loss: 0.0942 - accuracy: 0.9969 - val_loss: 0.0735 - val_accuracy: 1.0000
# Epoch 18/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 18: loss did not improve from 0.07360
# 10/10 [==============================] - 11s 1s/step - loss: 0.0740 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 1.0000
# Epoch 19/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1009 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 19: loss did not improve from 0.07360
# 10/10 [==============================] - 9s 1s/step - loss: 0.1009 - accuracy: 0.9937 - val_loss: 0.0733 - val_accuracy: 1.0000
# Epoch 20/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 20: loss did not improve from 0.07360
# 10/10 [==============================] - 9s 906ms/step - loss: 0.0740 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 1.0000
# Epoch 21/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 21: loss did not improve from 0.07360
# 10/10 [==============================] - 13s 1s/step - loss: 0.0741 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 1.0000
# Epoch 22/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 22: loss did not improve from 0.07360
# 10/10 [==============================] - 10s 939ms/step - loss: 0.0824 - accuracy: 0.9969 - val_loss: 0.0728 - val_accuracy: 1.0000
# Epoch 23/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0969 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 23: loss did not improve from 0.07360
# 10/10 [==============================] - 9s 829ms/step - loss: 0.0969 - accuracy: 0.9937 - val_loss: 0.0748 - val_accuracy: 1.0000
# Epoch 24/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 24: loss did not improve from 0.07360
# 10/10 [==============================] - 9s 902ms/step - loss: 0.0981 - accuracy: 0.9937 - val_loss: 0.0818 - val_accuracy: 1.0000
# Epoch 25/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 25: loss did not improve from 0.07360
# 10/10 [==============================] - 10s 1s/step - loss: 0.0858 - accuracy: 0.9969 - val_loss: 0.0756 - val_accuracy: 1.0000
# Epoch 26/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 26: loss did not improve from 0.07360
# 10/10 [==============================] - 10s 1s/step - loss: 0.0998 - accuracy: 0.9969 - val_loss: 0.0764 - val_accuracy: 1.0000
# Epoch 27/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1000 - accuracy: 0.9906WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 27: loss did not improve from 0.07360
# 10/10 [==============================] - 10s 1s/step - loss: 0.1000 - accuracy: 0.9906 - val_loss: 0.0764 - val_accuracy: 1.0000
# Epoch 28/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 28: loss did not improve from 0.07360
# 10/10 [==============================] - 10s 1s/step - loss: 0.0768 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 1.0000
# Epoch 29/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0769 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 29: loss did not improve from 0.07360
# 10/10 [==============================] - 10s 1000ms/step - loss: 0.0769 - accuracy: 1.0000 - val_loss: 0.0832 - val_accuracy: 1.0000
# Epoch 30/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 30: loss did not improve from 0.07360
# 10/10 [==============================] - 12s 1s/step - loss: 0.1125 - accuracy: 0.9937 - val_loss: 0.0777 - val_accuracy: 1.0000
# Epoch 31/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0766 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 31: loss did not improve from 0.07360
# 10/10 [==============================] - 10s 1s/step - loss: 0.0766 - accuracy: 1.0000 - val_loss: 0.0768 - val_accuracy: 1.0000
# Epoch 32/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 0.9906WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 32: loss did not improve from 0.07360
# 10/10 [==============================] - 9s 898ms/step - loss: 0.0926 - accuracy: 0.9906 - val_loss: 0.0773 - val_accuracy: 1.0000
# Epoch 33/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 33: loss did not improve from 0.07360
# 10/10 [==============================] - 10s 945ms/step - loss: 0.0776 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 1.0000
# Epoch 34/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 34: loss did not improve from 0.07360
# 10/10 [==============================] - 10s 979ms/step - loss: 0.0793 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 1.0000
# Epoch 35/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 35: loss did not improve from 0.07360
# 10/10 [==============================] - 11s 1s/step - loss: 0.0774 - accuracy: 1.0000 - val_loss: 0.0770 - val_accuracy: 1.0000
# Epoch 36/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1237 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 36: loss did not improve from 0.07360
# 10/10 [==============================] - 10s 1s/step - loss: 0.1237 - accuracy: 0.9937 - val_loss: 0.0772 - val_accuracy: 1.0000
# Epoch 37/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 37: loss did not improve from 0.07360
# 10/10 [==============================] - 9s 908ms/step - loss: 0.0774 - accuracy: 1.0000 - val_loss: 0.0777 - val_accuracy: 1.0000
# Epoch 38/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 38: loss did not improve from 0.07360
# 10/10 [==============================] - 10s 1s/step - loss: 0.0785 - accuracy: 1.0000 - val_loss: 0.0779 - val_accuracy: 1.0000
# Epoch 39/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 39: loss did not improve from 0.07360
# 10/10 [==============================] - 11s 1s/step - loss: 0.0774 - accuracy: 1.0000 - val_loss: 0.0768 - val_accuracy: 1.0000
# Epoch 40/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0762 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 40: loss did not improve from 0.07360
# 10/10 [==============================] - 12s 1s/step - loss: 0.0762 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 1.0000
# Epoch 41/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0754 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 41: loss did not improve from 0.07360
# 10/10 [==============================] - 9s 884ms/step - loss: 0.0754 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 1.0000
# Epoch 42/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0747 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 42: loss did not improve from 0.07360
# 10/10 [==============================] - 11s 1s/step - loss: 0.0747 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 1.0000
# Epoch 43/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 43: loss did not improve from 0.07360
# 10/10 [==============================] - 12s 1s/step - loss: 0.0739 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 1.0000
# Epoch 44/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 44: loss improved from 0.07360 to 0.07334, saving model to fire_detector.hdf5
# 10/10 [==============================] - 10s 1s/step - loss: 0.0733 - accuracy: 1.0000 - val_loss: 0.0727 - val_accuracy: 1.0000
# Epoch 45/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0725 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 45: loss improved from 0.07334 to 0.07249, saving model to fire_detector.hdf5
# 10/10 [==============================] - 11s 1s/step - loss: 0.0725 - accuracy: 1.0000 - val_loss: 0.0719 - val_accuracy: 1.0000
# Epoch 46/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0716 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 46: loss improved from 0.07249 to 0.07160, saving model to fire_detector.hdf5
# 10/10 [==============================] - 9s 900ms/step - loss: 0.0716 - accuracy: 1.0000 - val_loss: 0.0712 - val_accuracy: 1.0000
# Epoch 47/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 47: loss improved from 0.07160 to 0.07081, saving model to fire_detector.hdf5
# 10/10 [==============================] - 11s 1s/step - loss: 0.0708 - accuracy: 1.0000 - val_loss: 0.0704 - val_accuracy: 1.0000
# Epoch 48/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 48: loss improved from 0.07081 to 0.07006, saving model to fire_detector.hdf5
# 10/10 [==============================] - 11s 1s/step - loss: 0.0701 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 1.0000
# Epoch 49/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0693 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 49: loss improved from 0.07006 to 0.06931, saving model to fire_detector.hdf5
# 10/10 [==============================] - 12s 1s/step - loss: 0.0693 - accuracy: 1.0000 - val_loss: 0.0689 - val_accuracy: 1.0000
# Epoch 50/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0686 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 50: loss improved from 0.06931 to 0.06857, saving model to fire_detector.hdf5
# 10/10 [==============================] - 10s 1s/step - loss: 0.0686 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 1.0000
# Epoch 51/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 51: loss improved from 0.06857 to 0.06783, saving model to fire_detector.hdf5
# 10/10 [==============================] - 10s 1s/step - loss: 0.0678 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 1.0000
# Epoch 52/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 52: loss improved from 0.06783 to 0.06715, saving model to fire_detector.hdf5
# 10/10 [==============================] - 10s 1s/step - loss: 0.0672 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 1.0000
# Epoch 53/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 53: loss improved from 0.06715 to 0.06637, saving model to fire_detector.hdf5
# 10/10 [==============================] - 11s 1s/step - loss: 0.0664 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 1.0000
# Epoch 54/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 54: loss improved from 0.06637 to 0.06564, saving model to fire_detector.hdf5
# 10/10 [==============================] - 12s 1s/step - loss: 0.0656 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 1.0000
# Epoch 55/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0649 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 55: loss improved from 0.06564 to 0.06488, saving model to fire_detector.hdf5
# 10/10 [==============================] - 10s 1s/step - loss: 0.0649 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 1.0000
# Epoch 56/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 56: loss improved from 0.06488 to 0.06415, saving model to fire_detector.hdf5
# 10/10 [==============================] - 10s 1s/step - loss: 0.0641 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 1.0000
# Epoch 57/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 57: loss improved from 0.06415 to 0.06353, saving model to fire_detector.hdf5
# 10/10 [==============================] - 11s 1s/step - loss: 0.0635 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 1.0000
# Epoch 58/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0634 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 58: loss improved from 0.06353 to 0.06341, saving model to fire_detector.hdf5
# 10/10 [==============================] - 10s 977ms/step - loss: 0.0634 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 1.0000
# Epoch 59/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 59: loss improved from 0.06341 to 0.06222, saving model to fire_detector.hdf5
# 10/10 [==============================] - 12s 1s/step - loss: 0.0622 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 1.0000
# Epoch 60/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0614 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 60: loss improved from 0.06222 to 0.06143, saving model to fire_detector.hdf5
# 10/10 [==============================] - 10s 1s/step - loss: 0.0614 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 1.0000
# Epoch 61/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 61: loss improved from 0.06143 to 0.06067, saving model to fire_detector.hdf5
# 10/10 [==============================] - 10s 1s/step - loss: 0.0607 - accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 1.0000
# Epoch 62/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 62: loss improved from 0.06067 to 0.05995, saving model to fire_detector.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0599 - accuracy: 1.0000 - val_loss: 0.0595 - val_accuracy: 1.0000
# Epoch 63/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0608 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 63: loss did not improve from 0.05995
# 10/10 [==============================] - 9s 1s/step - loss: 0.0608 - accuracy: 1.0000 - val_loss: 0.0595 - val_accuracy: 1.0000
# Epoch 64/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0596 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 64: loss improved from 0.05995 to 0.05957, saving model to fire_detector.hdf5
# 10/10 [==============================] - 9s 924ms/step - loss: 0.0596 - accuracy: 1.0000 - val_loss: 0.0592 - val_accuracy: 1.0000
# Epoch 65/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 65: loss improved from 0.05957 to 0.05909, saving model to fire_detector.hdf5
# 10/10 [==============================] - 11s 1s/step - loss: 0.0591 - accuracy: 1.0000 - val_loss: 0.0584 - val_accuracy: 1.0000
# Epoch 66/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 66: loss did not improve from 0.05909
# 10/10 [==============================] - 9s 944ms/step - loss: 0.0650 - accuracy: 0.9969 - val_loss: 0.0605 - val_accuracy: 1.0000
# Epoch 67/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0706 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 67: loss did not improve from 0.05909
# 10/10 [==============================] - 12s 1s/step - loss: 0.0706 - accuracy: 0.9969 - val_loss: 0.0611 - val_accuracy: 1.0000
# Epoch 68/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 68: loss did not improve from 0.05909
# 10/10 [==============================] - 11s 1s/step - loss: 0.0662 - accuracy: 0.9969 - val_loss: 0.0627 - val_accuracy: 1.0000
# Epoch 69/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 69: loss did not improve from 0.05909
# 10/10 [==============================] - 11s 1s/step - loss: 0.0661 - accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 1.0000
# Epoch 70/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0802 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 70: loss did not improve from 0.05909
# 10/10 [==============================] - 10s 1s/step - loss: 0.0802 - accuracy: 0.9937 - val_loss: 0.0649 - val_accuracy: 1.0000
# Epoch 71/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0705 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 71: loss did not improve from 0.05909
# 10/10 [==============================] - 9s 967ms/step - loss: 0.0705 - accuracy: 0.9969 - val_loss: 0.0669 - val_accuracy: 1.0000
# Epoch 72/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0712 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 72: loss did not improve from 0.05909
# 10/10 [==============================] - 11s 1s/step - loss: 0.0712 - accuracy: 0.9969 - val_loss: 0.0677 - val_accuracy: 1.0000
# Epoch 73/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 73: loss did not improve from 0.05909
# 10/10 [==============================] - 11s 1s/step - loss: 0.0677 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 1.0000
# Epoch 74/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 74: loss did not improve from 0.05909
# 10/10 [==============================] - 11s 1s/step - loss: 0.0675 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 1.0000
# Epoch 75/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 75: loss did not improve from 0.05909
# 10/10 [==============================] - 11s 1s/step - loss: 0.0667 - accuracy: 1.0000 - val_loss: 0.0673 - val_accuracy: 1.0000
# Epoch 76/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 76: loss did not improve from 0.05909
# 10/10 [==============================] - 9s 952ms/step - loss: 0.0858 - accuracy: 0.9969 - val_loss: 0.0669 - val_accuracy: 1.0000
# Epoch 77/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 77: loss did not improve from 0.05909
# 10/10 [==============================] - 9s 906ms/step - loss: 0.0733 - accuracy: 0.9969 - val_loss: 0.0679 - val_accuracy: 1.0000
# Epoch 78/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 78: loss did not improve from 0.05909
# 10/10 [==============================] - 10s 982ms/step - loss: 0.0784 - accuracy: 0.9969 - val_loss: 0.0707 - val_accuracy: 1.0000
# Epoch 79/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9875WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 79: loss did not improve from 0.05909
# 10/10 [==============================] - 11s 1s/step - loss: 0.1426 - accuracy: 0.9875 - val_loss: 0.0735 - val_accuracy: 1.0000
# Epoch 80/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0762 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 80: loss did not improve from 0.05909
# 10/10 [==============================] - 11s 1s/step - loss: 0.0762 - accuracy: 1.0000 - val_loss: 0.0778 - val_accuracy: 1.0000
# Epoch 81/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9875WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 81: loss did not improve from 0.05909
# 10/10 [==============================] - 11s 1s/step - loss: 0.1135 - accuracy: 0.9875 - val_loss: 0.0806 - val_accuracy: 1.0000
# Epoch 82/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 82: loss did not improve from 0.05909
# 10/10 [==============================] - 11s 1s/step - loss: 0.0956 - accuracy: 0.9969 - val_loss: 0.0852 - val_accuracy: 1.0000
# Epoch 83/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1225 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 83: loss did not improve from 0.05909
# 10/10 [==============================] - 10s 1s/step - loss: 0.1225 - accuracy: 0.9937 - val_loss: 0.0906 - val_accuracy: 1.0000
# Epoch 84/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0930 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 84: loss did not improve from 0.05909
# 10/10 [==============================] - 8s 822ms/step - loss: 0.0930 - accuracy: 1.0000 - val_loss: 0.1053 - val_accuracy: 1.0000
# Epoch 85/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 85: loss did not improve from 0.05909
# 10/10 [==============================] - 9s 953ms/step - loss: 0.0926 - accuracy: 1.0000 - val_loss: 0.2731 - val_accuracy: 0.8000
# Epoch 86/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1353 - accuracy: 0.9906WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 86: loss did not improve from 0.05909
# 10/10 [==============================] - 10s 947ms/step - loss: 0.1353 - accuracy: 0.9906 - val_loss: 1.4051 - val_accuracy: 0.8000
# Epoch 87/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 87: loss did not improve from 0.05909
# 10/10 [==============================] - 12s 1s/step - loss: 0.1125 - accuracy: 0.9969 - val_loss: 2.9258 - val_accuracy: 0.8000
# Epoch 88/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 88: loss did not improve from 0.05909
# 10/10 [==============================] - 10s 1s/step - loss: 0.1400 - accuracy: 0.9937 - val_loss: 2.1316 - val_accuracy: 0.8000
# Epoch 89/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1068 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 89: loss did not improve from 0.05909
# 10/10 [==============================] - 9s 940ms/step - loss: 0.1068 - accuracy: 0.9937 - val_loss: 0.3073 - val_accuracy: 0.8000
# Epoch 90/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1007 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 90: loss did not improve from 0.05909
# 10/10 [==============================] - 10s 1s/step - loss: 0.1007 - accuracy: 1.0000 - val_loss: 0.2661 - val_accuracy: 0.8000
# Epoch 91/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1029 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 91: loss did not improve from 0.05909
# 10/10 [==============================] - 10s 1s/step - loss: 0.1029 - accuracy: 1.0000 - val_loss: 0.2260 - val_accuracy: 1.0000
# Epoch 92/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 92: loss did not improve from 0.05909
# 10/10 [==============================] - 11s 1s/step - loss: 0.1057 - accuracy: 0.9969 - val_loss: 0.1070 - val_accuracy: 1.0000
# Epoch 93/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 93: loss did not improve from 0.05909
# 10/10 [==============================] - 10s 979ms/step - loss: 0.1018 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 1.0000
# Epoch 94/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1171 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 94: loss did not improve from 0.05909
# 10/10 [==============================] - 11s 1s/step - loss: 0.1171 - accuracy: 0.9969 - val_loss: 0.1019 - val_accuracy: 1.0000
# Epoch 95/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1287 - accuracy: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 95: loss did not improve from 0.05909
# 10/10 [==============================] - 10s 998ms/step - loss: 0.1287 - accuracy: 0.9937 - val_loss: 0.5562 - val_accuracy: 0.8000
# Epoch 96/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1223 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 96: loss did not improve from 0.05909
# 10/10 [==============================] - 10s 1s/step - loss: 0.1223 - accuracy: 0.9969 - val_loss: 3.3795 - val_accuracy: 0.8000
# Epoch 97/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1098 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 97: loss did not improve from 0.05909
# 10/10 [==============================] - 11s 1s/step - loss: 0.1098 - accuracy: 0.9969 - val_loss: 3.0563 - val_accuracy: 0.8000
# Epoch 98/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 98: loss did not improve from 0.05909
# 10/10 [==============================] - 10s 995ms/step - loss: 0.1070 - accuracy: 1.0000 - val_loss: 2.6176 - val_accuracy: 0.8000
# Epoch 99/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 99: loss did not improve from 0.05909
# 10/10 [==============================] - 10s 967ms/step - loss: 0.1100 - accuracy: 0.9969 - val_loss: 2.1792 - val_accuracy: 0.8000
# Epoch 100/100
# 10/10 [==============================] - ETA: 0s - loss: 0.1078 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 100: loss did not improve from 0.05909
# 10/10 [==============================] - 11s 1s/step - loss: 0.1078 - accuracy: 1.0000 - val_loss: 1.5128 - val_accuracy: 0.8000

# %%
# сохраняем модель
model.save('gdrive/MyDrive/Fire_detecting/models/fire-datector-resnet50.hdf5')

# %%
# model.load_weights('gdrive/MyDrive/Fire_detecting/models/fire-datector-resnet50.hdf5')

# %%
# предсказываем класс тестовых картинок
test_pred = model.predict(
    predict_generator(test_files), steps=len(test_files), verbose=1)
# Out:
# 324/324 [==============================] - 85s 259ms/step

# %%
# визуализируем предсказания
fig = plt.figure(figsize=(16, 8))
for i, (path, score) in enumerate(zip(test_files[:15], test_pred[:15]), 1):
    subplot = fig.add_subplot(3, 5, i)
    subplot.set_title('%.2f %s' % (score, os.path.dirname(path).split('/')[-1]))
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    subplot.imshow(img)

fig.savefig('gdrive/MyDrive/Fire_detecting/predict')

# %%
# валидация на тренировочных данных
score = model.evaluate(fit_generator(train_files), verbose=1, steps=len(train_files))
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# 1297/1297 [==============================] - 1337s 1s/step - loss: 0.1118 - accuracy: 0.9992
# Validation loss: 0.11181634664535522
# Validation accuracy: 0.9992048740386963

# %%
# валидация на тестовых данных
score = model.evaluate(fit_generator(test_files), verbose=1, steps=len(test_files))
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# 324/324 [==============================] - 383s 1s/step - loss: 0.4369 - accuracy: 0.9755
# Validation loss: 0.43686628341674805
# Validation accuracy: 0.975501537322998

# %%
# посторение confusion matrix
labels = np.array([1 if os.path.dirname(path).split('/')[-1].startswith('Fire') else 0 for path in test_files])
con_mat = tf.math.confusion_matrix(labels=labels, predictions=np.around(test_pred)).numpy()
# con_mat_norm = np.around(con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis], decimals=2)
con_mat_df = pd.DataFrame(con_mat, index = [0,1], columns = [0,1])

# %%
con_mat_df
# Out:
#     0   1
# 0  71  81
# 1  81  91

# %%
# визуализация confusion matrix
figure = plt.figure(figsize=(5, 5))
sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
# формируем датасет с результатами и сохраняем в файл csv
ids = []
folder = []
prob = []
for path, score in zip(test_files, np.around(test_pred)):
    ids.append((os.path.basename(path)))
    folder.append((os.path.dirname(path).split('/')[-1]))
    prob.append(score[0])

# %%
output = pd.DataFrame({'id': ids, 'folder': folder, 'label': prob})
output.to_csv('gdrive/MyDrive/Fire_detecting/submission.csv', index=False)

# %%
output.head(20)
# Out:
#                                                    id           folder  label
# 0                   AdvisoryCouncilMeeting477x318.jpg  Normal Images 1    0.0
# 1                                         fire.90.png    Fire images 2    1.0
# 2                                        fire.295.png    Fire images 2    0.0
# 3                                    non_fire.105.png  Normal Images 6    0.0
# 4                         Late_model_Ford_Model_T.jpg  Normal Images 3    0.0
# 5                                    non_fire.238.png  Normal Images 6    0.0
# 6                                        fire.220.png    Fire images 2    1.0
# 7                                         fire.56.png    Fire images 2    1.0
# 8                                        fire.154.png    Fire images 2    1.0
# 9                     burning-charcoal-briquettes.jpg    Fire images 1    0.0
# 10                                       fire.210.png    Fire images 2    0.0
# 11                                   non_fire.241.png  Normal Images 6    1.0
# 12                                       fire.600.png    Fire images 2    1.0
# 13  b4d7b6e907c47ebb74058bac9d1953f1d138cb43b66042...  Normal Images 2    1.0
# 14                                       fire.435.png    Fire images 2    0.0
# 15                                   non_fire.187.png  Normal Images 6    1.0
# 16                               grimstad gate 02.jpg  Normal Images 2    0.0
# 17                 Office-Space-Photo-Open-Design.jpg  Normal Images 4    0.0
# 18                                   1453758_orig.jpg  Normal Images 1    1.0
# 19                                       fire.253.png    Fire images 2    1.0
